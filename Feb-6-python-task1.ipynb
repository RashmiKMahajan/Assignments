# %% [markdown]
# Name : Rashmi Mahajan
# Batch : Data science Masters / IMPACT
# Mentor : Sudhansu Kumar
# Topic : Python Task1
# Date : 3/2/2023

# %% [markdown]
# Q1. Create a function which will take a list as an argument and return the product of all the numbers after creating a flat list. Use the below-given list as an argument for your function. list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45, 22, 61, 34)}, [56, 'data science'], 'Machine Learning'] Note: you must extract numeric keys and values of the dictionary also.

# %%
# Give list
list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45, 22, 61, 34)}, [56, 'data science'], 'Machine Learning']
list1
# Out:
# [1,
#  2,
#  3,
#  4,
#  [44, 55, 66, True],
#  False,
#  (34, 56, 78, 89, 34),
#  {1, 2, 3},
#  {1: 34, 'key2': [55, 67, 78, 89], 4: (45, 22, 61, 34)},
#  [56, 'data science'],
#  'Machine Learning']

# %%
# Function return numeric values in given list containng nested list,tuple,set,integers
def numeric(a):
    l1_num = []
    for i in a:
        if type(i)==list:
            for j in i:
                if type(j)==int or type(j)==float:
                    l1_num.append(j)
        elif type(i)==int or type(i)==float:
              l1_num.append(i)
        elif type(i)== tuple:
            for t in i:
                if type(t)==int or type(t)==float:
                     l1_num.append(t)
        elif type(i) == set:
            for s in i:
                if type(s)==int or type(s)==float:
                     l1_num.append(s)
    return l1_num

# %%
la = numeric(list1) 
la
# Out:
# [1, 2, 3, 4, 44, 55, 66, 34, 56, 78, 89, 34, 1, 2, 3, 56]

# %%
# function to extract (key value pair ) Dictionary prsent in list1
def dictionary(a):
    for i in a:
        if type(i) == dict:
            lq = list(i.items())
    return lq

# %%
lq= dictionary(list1)
lq
# Out:
# [(1, 34), ('key2', [55, 67, 78, 89]), (4, (45, 22, 61, 34))]

# %%
#d= {1: 34, 'key2': [55, 67, 78, 89], 4: (45, 22, 61, 34)}
#d

# %%
#lq = list(d.items())
#lq

# %%
# code to return Numeric vales inside dictionary(numeric keys and values) present insid given list list1
def dict_num(lq):
    ld = []
    for i in lq:
        if type(i) == tuple:
            for t in i:
                if type(t)==int or type(t)==float:
                    ld.append(t)
                elif type(t) == list:
                    for j in t:
                        if type(j)==int or type(j)==float:
                            ld.append(j)
                elif type(t) == tuple:
                    for t1 in t:
                        if type(t1)==int or type(t1)==float:
                            ld.append(t1)
    return ld

# %%
Lq = dict_num(lq)
Lq
# Out:
# [1, 34, 55, 67, 78, 89, 4, 45, 22, 61, 34]

# %%
list1
# Out:
# [1,
#  2,
#  3,
#  4,
#  [44, 55, 66, True],
#  False,
#  (34, 56, 78, 89, 34),
#  {1, 2, 3},
#  {1: 34, 'key2': [55, 67, 78, 89], 4: (45, 22, 61, 34)},
#  [56, 'data science'],
#  'Machine Learning']

# %%
L=la + Lq
L
# Out:
# [1,
#  2,
#  3,
#  4,
#  44,
#  55,
#  66,
#  34,
#  56,
#  78,
#  89,
#  34,
#  1,
#  2,
#  3,
#  56,
#  1,
#  34,
#  55,
#  67,
#  78,
#  89,
#  4,
#  45,
#  22,
#  61,
#  34]

# %%
#from functools import reduce
from functools import reduce

# %%
# this is Final output
reduce(lambda x,y:x*y ,L)
# Out:
# 4134711838987085478833841242112000

# %% [markdown]
# Q2. Write a python program for encrypting a message sent to you by your friend. The logic of encryption should be such that, for a the output should be z. For b, the output should be y. For c, the output should be x respectively. Also, the whitespace should be replaced with a dollar sign. Keep the punctuation marks unchanged. Input Sentence: I want to become a Data Scientist. Encrypt the above input sentence using the program you just created. Note: Convert the given input sentence into lowercase before encrypting. The final output should be lowercase.

# %%
string = input('Enter your string for encription : - ')
str_lower = string.lower()
str_lower
# Out:
# Enter your string for encription : -  I want to become a Data Scientist
# 'i want to become a data scientist'

# %%
s = "Rashmi K Mahajan"
s1 = s.lower()
s1
# Out:
# 'rashmi k mahajan'

# %%
# Function to encrypt given string
def encrypt_str(str1):
    for i in str1:
        if i == 'a':
            i = (i.replace('a','z'))
        elif i == 'b':
            i = (i.replace('b','y'))
        elif i == 'c':
            i = (i.replace('c','x'))
        elif i == 'd':  
            i = (i.replace('d','w'))        
        elif i == 'e':
            i = (i.replace('e','v'))
        elif i == 'f':
            i = (i.replace('f','u'))
        elif i == 'g':
            i = (i.replace('g','t'))
        elif i == 'h':
            i = (i.replace('h','s'))
        elif i == 'i':
            i = (i.replace('i','r'))
        elif i == 'j':
            i = (i.replace('j','q'))
        elif i == 'k':
            i = (i.replace('k','p'))
        elif i == 'l':
            i = (i.replace('l','o'))
        elif i == 'm':
            i = (i.replace('m','n'))
        elif i == 'n':
            i = (i.replace('n','m'))
        elif i == 'o':
            i = (i.replace('o','l'))     
        elif i == 'p':
            i = (i.replace('p','k'))       
        elif i == 'q':
            i = (i.replace('q','j'))
        elif i == 'r':
            i = (i.replace('r','i'))      
        elif i == 's':
            i = (i.replace('s','h'))
        elif i == 't':
            i = (i.replace('t','g'))
        elif i == 'u':
            i = (i.replace('u','f'))
        elif i == 'v':
            i = (i.replace('v','e'))
        elif i == 'w':
            i = (i.replace('w','d'))
        elif i == 'x':
            i = (i.replace('x','c'))
        elif i == 'y':
            i = (i.replace('y','b'))
        elif i == 'z':
            i = (i.replace('z','a'))
        elif i == ' ':    
            i = (i.replace(' ','$'))
        print(i)   
    return(str1)

# %%
# function calling and string as an input taken from User 
new_str = encrypt_str(str_lower)
new_str
# Out:
# r
# $
# d
# z
# m
# g
# $
# g
# l
# $
# y
# v
# x
# l
# n
# v
# $
# z
# $
# w
# z
# g
# z
# $
# h
# x
# r
# v
# m
# g
# r
# h
# g
# 'i want to become a data scientist'

# %%
# function calling for fixed string defined in code
new_str = encrypt_str(s1)
new_str
# Out:
# i
# z
# h
# s
# n
# r
# $
# p
# $
# n
# z
# s
# z
# q
# z
# m
# 'rashmi k mahajan'
