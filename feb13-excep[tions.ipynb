# %%
Name : Rashmi Mahajan
Batch : Data science Masters 
Topic : Exception Handling
Date : 13/2/2023

# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# The Exception class is a Super class which includes a number of properties that help identify the code location, the type, the help file, and the reason for the exception: StackTrace, InnerException, Message, HelpLink, HResult, Source, TargetSite, and Data.
#
# Built-in exceptions offer information about Python-related problems, and custom exceptions will add information about project-related problems. That way, you can design your code (and traceback, if an exception is raised) in a way that combines Python code with the language of the project.
#
# The class Exception and its subclasses are a form of Throwable that indicates conditions that a reasonable application might want to catch. The class Exception and any subclasses that are not also subclasses of RuntimeException are checked exceptions.
#
# Custom exceptions provide you the flexibility to add attributes and methods that are not part of a standard Java exception. These can store additional information, like an application-specific error code, or provide utility methods that can be used to handle or present the exception to a user.

# %% [markdown]
# When creating a custom exception, we need to inherit from the base Exception class because it provides the fundamental properties and behaviors of an exception, such as a message and a stack trace. By inheriting from the Exception class, our custom exception can use these properties and behaviors and inherit methods like str and repr to control how the exception is displayed. When creating a custom exception, we need to inherit from the base Exception class because it provides the fundamental properties and behaviors of an exception, such as a message and a stack trace. By inheriting from the Exception class, our custom exception can use these properties and behaviors and inherit methods like str and repr to control how the exception is displayed. Overall, using the Exception class as the base class for our custom exception provides us with a consistent and standardized way to create, handle, and display exceptions in our code.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
import logging

# %%
logging.basicConfig(filename="hierarchy.log",level=logging.DEBUG)

# %%
def exception_hierarchy(exceptions, level=0):
    for exception in exceptions:
        logging.info('\t' * level + exception.__name__)
        if exception.__subclasses__():
            exception_hierarchy(exception.__subclasses__(), level + 1)

exception_hierarchy([BaseException])

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
#
# exception ArithmeticError
# The base class for those built-in exceptions that are raised for various arithmetic errors:
# 1. OverflowError,
# Raised when the result of an arithmetic operation is too large to be represented. This cannot occur for integers (which would rather raise MemoryError than give up). However, for historical reasons, OverflowError is sometimes raised for integers that are outside a required range. Because of the lack of standardization of floating point exception handling in C, most floating point operations are not checked.
#
# 2. ZeroDivisionError,
# Raised when the second argument of a division or modulo operation is zero. The associated value is a string indicating the type of the operands and the operation.
#
# 3. FloatingPointError.
# The arithmetic error occurs when an error is encountered during numeric calculations in Python. This includes Zerodivision Error and Floating point error. In addition, zero division error is raised when you divide a numeric value by zero. number = 6 ZeroErro = 6 / 0.
#
# ArithmeticException inherits from the RuntimeException class which means it is an unchecked, runtime exception

# %%
#  ZeroDivisionError
try:
    arithmetic = 6/0
    print(arithmetic)
except ArithmeticError as e:
    print('You have just made an Arithmetic error:- ', e)
# Out:
# You have just made an Arithmetic error:-  division by zero

# %% [markdown]
# Explanation
# Line 1: comment
# Line 2: We introduce the try, except block to help us check for errors in our line of codes.
# Line 3: We create a variable, arithmetic.
# Line 4: We return the output of our variable.
# Line 5: We use except to check for an ArithmeticError and complete the block.
# Line 6: If there is an ArithmeticError in our code, we have previously told Python to return a text output instead of crashing our program with error name.

# %%
# Handling OverflowError
j = 5.0
try:
    for i in range(1, 10000):
        j = j**i
except ArithmeticError as e:
    print('error is :-',e)
# Out:
# error is :- (34, 'Numerical result out of range')

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
#
# Lookup Error acts as a base class for the exceptions that occur when a key or index used on a mapping or sequence of a list/dictionary is invalid or does not exists.
#
# LookupError Exception is the Base class for errors raised when something can't be found. The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError. An IndexError is raised when a sequence reference is out of range.
#
# IndexError : It is raised when trying to access an invalid index within a list ,
# KeyError : It is raised when accessing an invalid key within a dictionary .

# %%
# IndexError
try:
    my_list = [3,7, 9, 4, 6]
    print(my_list[6])
except IndexError as e:
    print('error is :- ', e)
# Out:
# error is :-  list index out of range

# %%
# Key error
my_info = {'name': 'Sagar Mishra',
           'age': 28,
           'language': 'Python'}
user_input = input('What do you want to learn about my_info  ==> ')

try:
    print(' {} is {}'.format(user_input,my_info[user_input]))
except LookupError as e:
    print("Error is :- ",e , e.__class__)
# Out:
# What do you want to learn about my_info  ==>  phone_number
# Error is :-  'phone_number' <class 'KeyError'>

# %%
# other example for KeyError
try:
    s = {'a':5, 'b':7}['c']
except:
    print("Error is :" , e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       2 try:
# ----> 3     s = {'a':5, 'b':7}['c']
#       4 except:
#
# KeyError: 'c'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3     s = {'a':5, 'b':7}['c']
#       4 except:
# ----> 5     print("Error is :" , e)
#
# NameError: name 'e' is not defined

# %%
# Keyerror   ages.py
ages = {'Jim': 30, 'Pam': 28, 'Kevin': 33}
person = input('Get age for: ')

try:
    print(f'{person} is {ages[person]} years old.')
except KeyError as e:
    print("error in :- ", e ,"error type : - ",e.__class__)
    print(f"{person}'s age is unknown.")
# Out:
# Get age for:  rashmi
# error in :-  'rashmi' error type : -  <class 'KeyError'>
# rashmi's age is unknown.

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?
#
# The ImportError is raised when an import statement has trouble successfully importing the specified module. Typically, such a problem is due to an invalid or incorrect path, which will raise a ModuleNotFoundError in Python
#
# How do I fix the ImportError No module named error in Python?
# This can happen if you've misspelled the module name, or if you're trying to import a module that's not in your Python path. To fix this, make sure you're using the correct module name, and that the module is in your Python path (or at least in your project directory where you're executing your main . py file from.)
#
# The ImportError: cannot import name can be fixed using the following approaches, depending on the cause of the error:
#
# 1. If the error occurs due to a circular dependency, it can be resolved by moving the imported classes to a third file and importing them from this file.
# 2. If the error occurs due to a misspelled name, the name of the class in the Python file should be verified and corrected.
# 3. If the imported class is unavailable or not created, the file should be checked to ensure that the imported class exists in the file. If not, it should be created.
# 4. If the imported class from a module is misplaced, it should be ensured that the class is imported from the correct module.

# %% [markdown]
# The 'module not found' error is a syntax error that appears when the static import statement cannot find the file at the declared path. This common syntax error is caused by letter-casing inconsistencies that are present in your filename(s) between your repository and local machine, or both.
#
# What causes ModuleNotFoundError?
# Here are a few reasons why a module may not be found: you do not have the module you tried importing installed on your computer. you spelled a module incorrectly (which still links back to the previous point, that the misspelled module is not installed)...for example, spelling numpy as numpys during import.

# %%
# ImportError & ModuleNotFoundError
import numpys
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # ImportError & ModuleNotFoundError
# ----> 2 import numpys
#
# ModuleNotFoundError: No module named 'numpys'

# %%
try:
    import non_existent_module
except ImportError:
    logging.info("An error occurred while importing the module.")
    
try:
    import missing_submodule.submodule2
except ModuleNotFoundError:
    logging.info("The specified module or submodule could not be found.")

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %%
#Always use logging instead of print
try:
    10/0
except ZeroDivisionError as e:
    logging.info("i want to find zerodivisionerror {} ".format(e))

# %%
#Always print a proper message
try:
    10/0
except ZeroDivisionError as e:
    logging.info("i want to find zerodivisionerror {} ".format(e))

# %%
#Always try to specific an exception
try:
    10/0
except ZeroDivisionError as e:
    logging.info(e)

# %%
# Document all the error
#clenup all the resources
try:
    with open("test.txt","w") as f:
        f.write("this is my data to file ")
except FileNotFoundError as e:
    logging.error("i am handling file not found{}".format(e))
finally:
    f.close()

# %%
#Always avoid writing multiple exception 
try:
    10/0
except FileNotFoundError as e:
    logging.error("i am trying to find filenotfound error {}".format(e))
except AttributeError as e:
    logging.error("i am trying to find attributeerror {}".format(e))
except ZeroDivisionError as e:
    logging.error("i am trying to find Zerodivision error{}".format(e))
